# %% [markdown]
# # Import Necessary Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
jan=pd.read_csv("SalesData/Sales_January_2019.csv")
jan
# Out:
#      Order ID                   Product Quantity Ordered Price Each
# 0      141234                    iPhone                1        700  \
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %% [markdown]
# # Fetch filename From Folder

# %%
filenames=os.listdir('SalesData')
filenames
# Out:
# ['city.csv',
#  'Monthlysales.png',
#  'Monthwise_pie_sales.png',
#  'Monthwise_sales.png',
#  'order_bytime.png',
#  'Sales.csv',
#  'Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv',
#  'TopMonth.csv',
#  'totalsales.png']

# %%
edf =pd.DataFrame()
edf
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Read / Load data one by one

# %%
for filename in filenames:
    df=pd.read_csv(f'SalesData/{filename}')
    edf=pd.concat([edf,df])
edf
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[146], line 2
#       1 for filename in filenames:
# ----> 2     df=pd.read_csv(f'SalesData/{filename}')
#       3     edf=pd.concat([edf,df])
#       4 edf
#
# ...

# %% [markdown]
# # Convert edf file to CSV file

# %%
edf.to_csv('SalesData/Sales.csv')

# %% [markdown]
# # Explore Sales

# %%
df=pd.read_csv('SalesData/Sales.csv')
df

# %%
df.info()

# %% [markdown]
# # Isnull()

# %%
df.isnull().sum()

# %% [markdown]
# # Delete empty rows

# %%
df=df.dropna(how='all')
df

# %%
df.info()

# %%
df.isnull().sum()

# %% [markdown]
# # Type Conversion

# %%
df['Quantity Ordered'].astype(int)

# %% [markdown]
# # Filter out Wrong data

# %%
df=df.loc[df['Quantity Ordered']!='Quantity Ordered']
df
# Out:
#         Unnamed: 0  Order ID                     Product  Quantity Ordered
# 0                0    176558        USB-C Charging Cable                 2  \
# 1                2    176559  Bose SoundSport Headphones                 1
# 2                3    176560                Google Phone                 1
# 3                4    176560            Wired Headphones                 1
# 4                5    176561            Wired Headphones                 1
# ...            ...       ...                         ...               ...
# 185945      186845    259353      AAA Batteries (4-pack)                 3
# 185946      186846    259354                      iPhone                 1
# 185947      186847    259355                      iPhone                 1
# 185948      186848    259356      34in Ultrawide Monitor                 1
# 185949      186849    259357        USB-C Charging Cable                 1
#
# ...

# %% [markdown]
# # Resave

# %%
df.to_csv('SalesData/Sales.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185950 entries, 0 to 185949
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        185950 non-null  int64
#  1   Order ID          185950 non-null  int64
#  2   Product           185950 non-null  object
#  3   Quantity Ordered  185950 non-null  int64
#  4   Price Each        185950 non-null  float64
#  5   Order Date        185950 non-null  object
#  6   Purchase Address  185950 non-null  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 11.3+ MB

# %%
df=pd.read_csv('SalesData/Sales.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Order ID                     Product
# 0             0           0    176558        USB-C Charging Cable  \
# 1             1           2    176559  Bose SoundSport Headphones
# 2             2           3    176560                Google Phone
# 3             3           4    176560            Wired Headphones
# 4             4           5    176561            Wired Headphones
#
#    Quantity Ordered  Price Each       Order Date
# 0                 2       11.95   4/19/2019 8:46  \
# 1                 1       99.99   4/7/2019 22:30
# 2                 1      600.00  4/12/2019 14:38
# 3                 1       11.99  4/12/2019 14:38
# 4                 1       11.99   4/30/2019 9:27
#
#                        Purchase Address
# 0          917 1st St, Dallas, TX 75001
# 1     682 Chestnut St, Boston, MA 02215
# 2  669 Spruce St, Los Angeles, CA 90001
# 3  669 Spruce St, Los Angeles, CA 90001
# 4     333 8th St, Los Angeles, CA 90001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0.1      185950 non-null  int64
#  1   Unnamed: 0        185950 non-null  int64
#  2   Order ID          185950 non-null  int64
#  3   Product           185950 non-null  object
#  4   Quantity Ordered  185950 non-null  int64
#  5   Price Each        185950 non-null  float64
#  6   Order Date        185950 non-null  object
#  7   Purchase Address  185950 non-null  object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 11.3+ MB

# %% [markdown]
# # Convert to Date Time

# %%
df['Order Date'] =pd.to_datetime(df['Order Date'])
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Order ID                     Product
# 0             0           0    176558        USB-C Charging Cable  \
# 1             1           2    176559  Bose SoundSport Headphones
# 2             2           3    176560                Google Phone
# 3             3           4    176560            Wired Headphones
# 4             4           5    176561            Wired Headphones
#
#    Quantity Ordered  Price Each          Order Date
# 0                 2       11.95 2019-04-19 08:46:00  \
# 1                 1       99.99 2019-04-07 22:30:00
# 2                 1      600.00 2019-04-12 14:38:00
# 3                 1       11.99 2019-04-12 14:38:00
# 4                 1       11.99 2019-04-30 09:27:00
#
#                        Purchase Address
# 0          917 1st St, Dallas, TX 75001
# 1     682 Chestnut St, Boston, MA 02215
# 2  669 Spruce St, Los Angeles, CA 90001
# 3  669 Spruce St, Los Angeles, CA 90001
# 4     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# # Creating a New Column 'Amount'

# %%
df['Amount'] = df['Quantity Ordered']*df['Price Each']
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Order ID                     Product
# 0             0           0    176558        USB-C Charging Cable  \
# 1             1           2    176559  Bose SoundSport Headphones
# 2             2           3    176560                Google Phone
# 3             3           4    176560            Wired Headphones
# 4             4           5    176561            Wired Headphones
#
#    Quantity Ordered  Price Each          Order Date
# 0                 2       11.95 2019-04-19 08:46:00  \
# 1                 1       99.99 2019-04-07 22:30:00
# 2                 1      600.00 2019-04-12 14:38:00
# 3                 1       11.99 2019-04-12 14:38:00
# 4                 1       11.99 2019-04-30 09:27:00
#
#                        Purchase Address  Amount
# 0          917 1st St, Dallas, TX 75001   23.90
# 1     682 Chestnut St, Boston, MA 02215   99.99
# 2  669 Spruce St, Los Angeles, CA 90001  600.00
# 3  669 Spruce St, Los Angeles, CA 90001   11.99
# ...

# %% [markdown]
# # Analysis -1 Total Sales

# %%
df['Amount'].sum()
# Out:
# 34492035.97

# %% [markdown]
# # What was the best month for sales? How much was earned that month?

# %% [markdown]
# # Fetching month from date

# %%
df['Month'] = df['Order Date'].dt.month
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Order ID                     Product
# 0             0           0    176558        USB-C Charging Cable  \
# 1             1           2    176559  Bose SoundSport Headphones
# 2             2           3    176560                Google Phone
# 3             3           4    176560            Wired Headphones
# 4             4           5    176561            Wired Headphones
#
#    Quantity Ordered  Price Each          Order Date
# 0                 2       11.95 2019-04-19 08:46:00  \
# 1                 1       99.99 2019-04-07 22:30:00
# 2                 1      600.00 2019-04-12 14:38:00
# 3                 1       11.99 2019-04-12 14:38:00
# 4                 1       11.99 2019-04-30 09:27:00
#
#                        Purchase Address  Amount  Month
# 0          917 1st St, Dallas, TX 75001   23.90      4
# 1     682 Chestnut St, Boston, MA 02215   99.99      4
# 2  669 Spruce St, Los Angeles, CA 90001  600.00      4
# ...

# %%
df['Month_name'] = df['Order Date'].dt.month_name()
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Order ID                     Product
# 0             0           0    176558        USB-C Charging Cable  \
# 1             1           2    176559  Bose SoundSport Headphones
# 2             2           3    176560                Google Phone
# 3             3           4    176560            Wired Headphones
# 4             4           5    176561            Wired Headphones
#
#    Quantity Ordered  Price Each          Order Date
# 0                 2       11.95 2019-04-19 08:46:00  \
# 1                 1       99.99 2019-04-07 22:30:00
# 2                 1      600.00 2019-04-12 14:38:00
# 3                 1       11.99 2019-04-12 14:38:00
# 4                 1       11.99 2019-04-30 09:27:00
#
#                        Purchase Address  Amount  Month Month_name
# 0          917 1st St, Dallas, TX 75001   23.90      4      April
# 1     682 Chestnut St, Boston, MA 02215   99.99      4      April
# ...

# %%
mdf=df.groupby('Month_name').agg(totalsale=('Amount','sum'),avgsale=('Amount','mean'))
mdf=mdf.reset_index()
mdf=mdf.sort_values(by='totalsale',ascending=False)
mdf
# Out:
#    Month_name   totalsale     avgsale
# 2    December  4613443.34  184.655913
# 10    October  3736726.88  184.238580
# 0       April  3390670.24  185.495390
# 9    November  3199603.20  182.074956
# 8         May  3152606.75  190.305852
# 7       March  2807100.38  185.250471
# 5        July  2647775.76  185.249826
# 6        June  2577802.26  190.187565
# 1      August  2244467.88  187.648849
# 3    February  2202022.42  183.884962
# 11  September  2097560.13  180.497387
# 4     January  1822256.73  187.687376

# %%
mdf.to_csv('SalesData/TopMonth.csv',index=False)

# %% [markdown]
# # Visulaisation 1

# %%
plt.figure(figsize=(12,5))
plt.bar(mdf['Month_name'],mdf['totalsale'],color='orange')
plt.title('Sales')
plt.xlabel('Month')
plt.ylabel('TotalSale')
plt.xticks(rotation=45,color='grey')
plt.yticks()
plt.grid()
plt.savefig('SalesData/Monthlysales.png')

# %%
tdf=df.groupby(['Month','Month_name']).agg(totalsale=('Amount','sum'))
tdf=tdf.reset_index()
tdf
# Out:
#     Month Month_name   totalsale
# 0       1    January  1822256.73
# 1       2   February  2202022.42
# 2       3      March  2807100.38
# 3       4      April  3390670.24
# 4       5        May  3152606.75
# 5       6       June  2577802.26
# 6       7       July  2647775.76
# 7       8     August  2244467.88
# 8       9  September  2097560.13
# 9      10    October  3736726.88
# 10     11   November  3199603.20
# 11     12   December  4613443.34

# %%
plt.figure(figsize=(12,5))
plt.plot(tdf['Month_name'],tdf['totalsale'],color='orange')
plt.title('Sales',color ='green')
plt.xlabel('Month')
plt.ylabel('TotalSale')
plt.xticks(rotation=45,color='brown')
plt.yticks()
plt.grid()
plt.savefig('SalesData/Monthwise_sales.png')

# %%
plt.pie(tdf['totalsale'],labels=tdf['Month_name'],autopct='%.1f%%',radius=1.5)
plt.savefig('SalesData/Monthwise_pie_sales.png')

# %% [markdown]
# # What city sold the most product ?

# %%
s=df['Purchase Address'].str.split(',')
s
# Out:
# 0                    [917 1st St,  Dallas,  TX 75001]
# 1               [682 Chestnut St,  Boston,  MA 02215]
# 2            [669 Spruce St,  Los Angeles,  CA 90001]
# 3            [669 Spruce St,  Los Angeles,  CA 90001]
# 4               [333 8th St,  Los Angeles,  CA 90001]
#                              ...
# 185945     [840 Highland St,  Los Angeles,  CA 90001]
# 185946    [216 Dogwood St,  San Francisco,  CA 94016]
# 185947       [220 12th St,  San Francisco,  CA 94016]
# 185948     [511 Forest St,  San Francisco,  CA 94016]
# 185949     [250 Meadow St,  San Francisco,  CA 94016]
# Name: Purchase Address, Length: 185950, dtype: object

# %%
def city(l):
    return l[1]

s =df['Purchase Address'].str.split(',')
df['city'] =s.apply(city)
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  Order ID                     Product
# 0                  0           0    176558        USB-C Charging Cable  \
# 1                  1           2    176559  Bose SoundSport Headphones
# 2                  2           3    176560                Google Phone
# 3                  3           4    176560            Wired Headphones
# 4                  4           5    176561            Wired Headphones
# ...              ...         ...       ...                         ...
# 185945        185945      186845    259353      AAA Batteries (4-pack)
# 185946        185946      186846    259354                      iPhone
# 185947        185947      186847    259355                      iPhone
# 185948        185948      186848    259356      34in Ultrawide Monitor
# 185949        185949      186849    259357        USB-C Charging Cable
#
#         Quantity Ordered  Price Each          Order Date
# ...

# %%
d=df['Purchase Address'].str.split(',',expand=True)
df['city']=d[1]
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  Order ID                     Product
# 0                  0           0    176558        USB-C Charging Cable  \
# 1                  1           2    176559  Bose SoundSport Headphones
# 2                  2           3    176560                Google Phone
# 3                  3           4    176560            Wired Headphones
# 4                  4           5    176561            Wired Headphones
# ...              ...         ...       ...                         ...
# 185945        185945      186845    259353      AAA Batteries (4-pack)
# 185946        185946      186846    259354                      iPhone
# 185947        185947      186847    259355                      iPhone
# 185948        185948      186848    259356      34in Ultrawide Monitor
# 185949        185949      186849    259357        USB-C Charging Cable
#
#         Quantity Ordered  Price Each          Order Date
# ...

# %%
ndf=df.groupby('city').agg(totalquantity=('Quantity Ordered','sum'),totalsale=('Amount','sum'))
ndf.to_csv('SalesData/city.csv')

# %%
ndf=ndf.reset_index()
ndf=ndf.sort_values(by='totalsale',ascending=False)
ndf
# Out:
#              city  totalquantity   totalsale
# 7   San Francisco          50239  8262203.91
# 4     Los Angeles          33289  5452570.80
# 5   New York City          27932  4664317.43
# 2          Boston          22528  3661642.01
# 0         Atlanta          16602  2795498.58
# 3          Dallas          16730  2767975.40
# 8         Seattle          16553  2747755.48
# 6        Portland          14053  2320490.61
# 1          Austin          11153  1819581.75

# %%
ndf=ndf.reset_index(drop=True)
ndf
# Out:
#              city  totalquantity   totalsale
# 0   San Francisco          50239  8262203.91
# 1     Los Angeles          33289  5452570.80
# 2   New York City          27932  4664317.43
# 3          Boston          22528  3661642.01
# 4         Atlanta          16602  2795498.58
# 5          Dallas          16730  2767975.40
# 6         Seattle          16553  2747755.48
# 7        Portland          14053  2320490.61
# 8          Austin          11153  1819581.75

# %% [markdown]
# # City -graph

# %%
plt.figure(figsize=(12,5))
plt.bar(ndf['city'],ndf['totalsale'])
plt.xlabel('City')
plt.ylabel('TotalSale (in 10 lakhs)')

plt.savefig('SalesData/totalsales.png')

# %% [markdown]
# # What time should we display advertisemens to maximize the likelihood of customer’s buying product?

# %%
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  Order ID                     Product
# 0                  0           0    176558        USB-C Charging Cable  \
# 1                  1           2    176559  Bose SoundSport Headphones
# 2                  2           3    176560                Google Phone
# 3                  3           4    176560            Wired Headphones
# 4                  4           5    176561            Wired Headphones
# ...              ...         ...       ...                         ...
# 185945        185945      186845    259353      AAA Batteries (4-pack)
# 185946        185946      186846    259354                      iPhone
# 185947        185947      186847    259355                      iPhone
# 185948        185948      186848    259356      34in Ultrawide Monitor
# 185949        185949      186849    259357        USB-C Charging Cable
#
#         Quantity Ordered  Price Each          Order Date
# ...

# %%
df['time']=df['Order Date'].dt.hour
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  Order ID                     Product
# 0                  0           0    176558        USB-C Charging Cable  \
# 1                  1           2    176559  Bose SoundSport Headphones
# 2                  2           3    176560                Google Phone
# 3                  3           4    176560            Wired Headphones
# 4                  4           5    176561            Wired Headphones
# ...              ...         ...       ...                         ...
# 185945        185945      186845    259353      AAA Batteries (4-pack)
# 185946        185946      186846    259354                      iPhone
# 185947        185947      186847    259355                      iPhone
# 185948        185948      186848    259356      34in Ultrawide Monitor
# 185949        185949      186849    259357        USB-C Charging Cable
#
#         Quantity Ordered  Price Each          Order Date
# ...

# %%
sns.countplot(data=df,x='time')
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
plt.savefig('SalesData/order_bytime.png')

# %%
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))
df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0  Order ID                     Product
# 0             0           0    176558        USB-C Charging Cable  \
# 1             1           2    176559  Bose SoundSport Headphones
# 2             2           3    176560                Google Phone
# 3             3           4    176560            Wired Headphones
# 4             4           5    176561            Wired Headphones
# 5             5           6    176562        USB-C Charging Cable
# 6             6           7    176563  Bose SoundSport Headphones
# 7             7           8    176564        USB-C Charging Cable
# 8             8           9    176565          Macbook Pro Laptop
# 9             9          10    176566            Wired Headphones
#
#    Quantity Ordered  Price Each          Order Date
# 0                 2       11.95 2019-04-19 08:46:00  \
# 1                 1       99.99 2019-04-07 22:30:00
# 2                 1      600.00 2019-04-12 14:38:00
# ...

# %% [markdown]
# # What product sold the most? Why do you think it sold the most?

# %%
df.groupby('Product')['Quantity Ordered'].sum().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product'>
